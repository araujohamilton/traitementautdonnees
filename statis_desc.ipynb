# %% [markdown]
# # La statistique descriptive</h1>
#
# - Definition wikipedia : L'objectif de la statistique descriptive est de décrire, c'est-à-dire de résumer ou représenter, par des parametres et/ou des mesures (staistiques), les données disponibles quand elles sont nombreuses.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/DigiDB_digimonlist.csv')
data
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
#      Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0         590       77        79        69        68        95
# 1         950       62        76        76        69        68
# 2         870       50        97        87        50        75
# 3         690       68        77        95        76        61
# 4         540       98        54        59        95        86
# ..        ...      ...       ...       ...       ...       ...
# 244      1330      139       148       129       129       168
# 245      1980      114       228       104        84       168
# 246      1440      124       178       104       158       174
# 247      1040      133       149       139       144       213
# 248      1480      143       149       139       159       143
#
# [249 rows x 13 columns]

# %% [markdown]
# ## Les types de variables
#
# - <b>Les variables catégorielles (qualitatives) </b>
# <p> Il n'y a pas de notion d'échelle, c'est un attribut d'un critère<br>
# Exemples : [homme,Femme], [première classe, deuxième classe, troisième classe], [Vrai,Faux]<p>

# %%
sns.set(style="darkgrid")
sns.countplot(x="Type", data=data)

# %%
sns.countplot(x="Attribute", data=data)

# %%
sns.countplot(data['Attribute'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - <b>Les variables quantitatives </b>
#
# <p> A l'inverse, ces variables permettent de mesurer des quantités <br>
#     Il en existe 2 types : Variables quantitatives <b>discrètes</b> et <b>continues</b> </p>
#
# <b>Les variables quantitatives discrètes </b>
# <p> C'est une variable avec un nombre fini de valeurs <br>
# Exemples : nombre d'items, nombre de personnes <p>

# %%
#les variables quantitatives discrètes
sns.distplot(data['Memory'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(data['Memory'])

# %%
sns.distplot(list(data['Memory']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <b>Les variables quantitatives continues </b>
# <p> C'est une variable avec une infinité de valeurs <br>
# Exemples : poids, durée <p>
#
# <p>Pas de variable quantitative continue dans le data set !

# %% [markdown]
# # Les statistiques de base </h2>

# %% [markdown]
# Description d'une variable continue </b> <br>
#
# ## La moyenne
#
# Somme des valeurs de la variable divisée par le nombre d'individus
#
# ![image.png](data:image/png;base64,...)

# %%
data.head()
# Out:
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86

# %%
mean = data['Lv 50 HP'].mean()
mean
# Out:
# 1210.8835341365461

# %%
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## La Médiane
#
# valeur centrale qui partage l'échantillon en 2 groupes de même effectif: 50 % au-dessus et 50 % en dessous

# %%
median = data['Lv 50 HP'].median()
print(median)
plt.figure(figsize=(15,15))
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
plt.axvline(median, color='g')
# Out:
# 1180.0
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
#  ## La mode
#
#  C'est la valeur la plus fréquente dans le jeu de données

# %%
mode = data['Lv 50 HP'].mode()
print(mode)
sns.distplot(list(data['Lv 50 HP']))
plt.axvline(mean, color='r')
plt.axvline(median, color='g')
plt.axvline(float(mode), color='y')
# Out:
# 0    1480
# dtype: int64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.nunique()
# Out:
# Number         249
# Digimon        249
# Stage            8
# Type             4
# Attribute        9
# Memory          14
# Equip Slots      4
# Lv 50 HP        61
# Lv50 SP         75
# Lv50 Atk        83
# Lv50 Def        65
# Lv50 Int        79
# Lv50 Spd        75
# dtype: int64

# %%
nbValDif = len(data['Lv 50 HP'].unique())
plt.figure(figsize=(10,5))
sns.distplot(list(data['Lv 50 HP']), bins=nbValDif)
plt.axvline(mean, color='r')
plt.axvline(median, color='g')
plt.axvline(float(mode), color='y')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mode = data['Type'].mode()
mode
# Out:
# 0    Virus
# dtype: object

# %%
sns.countplot(x="Type", data=data)

# %% [markdown]
# ## la variance
#
# disparité dans notre jeu de données: moyenne arithmétique des carrés des écarts à la moyenne arithmétique observée
#
# ![image.png](data:image/png;base64,...)

# %%
variance = data['Lv 50 HP'].var()
variance
# Out:
# 106342.76460681435

# %% [markdown]
# ## L'écart type
#
# c'est la racine carrée de la variance
#
# ![image.png](data:image/png;base64,...)

# %%
ecartType = data['Lv 50 HP'].std()
ecartType
# Out:
# 326.1023836263917

# %%
variance**(1/2)
# Out:
# 326.1023836263917

# %% [markdown]
# ## Les quantiles
#
# Dans la même logique que la médiane les quartile vont couper la population en 4 parties contenant le même nombre d'observation
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
ax = sns.boxplot(x="Type", y="Lv 50 HP", data=data)
plt.show()

# %% [markdown]
# # La loi normale
#
# Quelques exemples
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Dans une expérience aléatoire, plus on augmente le nombre d'obeservations et plus la répartition va se lisser et se rapprocher de la fonction de gauss
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Distribution de la fonction de Gauss :
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <b> Calculer le coéficient d'assymétrie (skewness) de sa distribution </b>
#
# Fait référence à l'asymétrie des données. Lorsque les données sont concentrées sur le côté droit de l'histogramme, par exemple, nous disons qu'elles ont un skew négatif. Lorsque les données sont concentrées à gauche, on dit qu'elles ont un skew positif.
#
# ![image.png](data:image/png;base64,...)

# %%
data['Lv 50 HP'].skew()
# Out:
# 0.1374660716485841

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Calculer le coéficient d'applatissement d'une distribution : Kurtosis
#
# Plus la valeur d'aplatissement est élevée, plus le pic est élevé. Plus la valeur de kustose est faible, plus la valeur est étalée.
#
# ![image.png](data:image/png;base64,...)

# %%
data['Lv 50 HP'].kurtosis()
# Out:
# -0.5447522937424649

# %%
sns.distplot(list(data['Lv 50 HP']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Notion de correlation entre des variables et calcul du coefficient de correlation
#
# La correlation indique s'il y a une liaison entre 2 variables, c'est à dire determiner si les variables sont indépendantes ou non.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <b> Calcul du coeficient de corrélation (pour 2 variables) </b> <br>
#    - Étape 1 : calculer la covariance
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Étape 2 : calculer le coéficient de corrélation (valeur comprise entre -1 et 1)
#
# Plus le CC est eloigné de 0, plus la corrélation est forte, plus il est proche de 0 plus la corrélation est faible
#
# ![image.png](data:image/png;base64,...)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, figsize=(25,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9bd2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9c0a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9bc17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9b77dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9b3a410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9aefc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9ab3250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9a69690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9a696d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9a1dcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9999610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85ca0b00d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9f10e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9d79390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9b9a190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9909290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c98c0890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9876e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c98394d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c97f1ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c97b4110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c976a710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9723d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c96e7350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c969d950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9654f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9617590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c964db90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c95921d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c95ca7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9580dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9543410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c94faa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c94b0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9473650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c942ac50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c93f0290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c93a6890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c935ee90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c93214d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c92da7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c930fcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9253250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c928b750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c923fc10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9203150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c91ba650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9171b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c911cb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c90eb590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c90a1a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9059f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c901b4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8fd19d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9008ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8fcc410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8f82910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8f39e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8efc350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8eb2850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8e68d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8e2b290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8de3790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8d99c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8d5c1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8d136d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8d49bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85cd6b1c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c98cc250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c96aad10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c9543610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c936b9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8b955d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8bcabd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8b8e210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8b45810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8af9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8ac0450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8a75a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c8a23b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85c89f0690>]],
#       dtype=object)

# %%
sns.jointplot("Lv 50 HP", "Lv50 SP", data=data)
data[["Lv 50 HP", "Lv50 SP"]].corr()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#           Lv 50 HP   Lv50 SP
# Lv 50 HP  1.000000  0.070957
# Lv50 SP   0.070957  1.000000

# %%
sns.jointplot("Lv50 Int", "Lv50 SP", data=data)
data[["Lv50 Int", "Lv50 SP"]].corr()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#           Lv50 Int   Lv50 SP
# Lv50 Int  1.000000  0.895652
# Lv50 SP   0.895652  1.000000

# %%
data.corr()
# Out:
#                Number    Memory  Equip Slots  Lv 50 HP   Lv50 SP  Lv50 Atk  \
# Number       1.000000  0.923339     0.571901  0.626166  0.608113  0.552471
# Memory       0.923339  1.000000     0.355176  0.639569  0.623400  0.608372
# Equip Slots  0.571901  0.355176     1.000000  0.392137  0.278687  0.211450
# Lv 50 HP     0.626166  0.639569     0.392137  1.000000  0.070957  0.605708
# Lv50 SP      0.608113  0.623400     0.278687  0.070957  1.000000 -0.148365
# Lv50 Atk     0.552471  0.608372     0.211450  0.605708 -0.148365  1.000000
# Lv50 Def     0.620177  0.611728     0.466534  0.561376  0.169960  0.426901
# Lv50 Int     0.560146  0.583956     0.237616  0.055314  0.895652 -0.186125
# Lv50 Spd     0.762861  0.797777     0.286558  0.317051  0.603240  0.522005
#
#              Lv50 Def  Lv50 Int  Lv50 Spd
# Number       0.620177  0.560146  0.762861
# Memory       0.611728  0.583956  0.797777
# Equip Slots  0.466534  0.237616  0.286558
# Lv 50 HP     0.561376  0.055314  0.317051
# Lv50 SP      0.169960  0.895652  0.603240
# Lv50 Atk     0.426901 -0.186125  0.522005
# Lv50 Def     1.000000  0.182606  0.225921
# Lv50 Int     0.182606  1.000000  0.442214
# Lv50 Spd     0.225921  0.442214  1.000000

# %%
sns.heatmap(data.corr())
